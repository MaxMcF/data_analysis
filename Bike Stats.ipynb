# %%
import csv
import pandas as pd
import numpy as np
import datetime as dt
import math

# %%
st = pd.read_csv('./station.csv')
tr = pd.read_csv('./trip.csv', error_bad_lines=False)
we = pd.read_csv('./weather.csv')
# Out:
# b'Skipping line 50794: expected 12 fields, saw 20\n'

# %%
st.modification_date = [st.decommission_date != None
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-048548ed0db0> in <module>()
# ----> 1 st.modification_date = None[st.decommission_date != None]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
tr.tripduration.mean()
# Out:
# 1178.2956753399776

# %%
mode_of_ages = tr.birthyear.mode()

# %%
dt.datetime.now().year - mode_of_ages
# Out:
# 0    31.0
# dtype: float64

# %%
# Out:
#          Date  Max_Temperature_F  Mean_Temperature_F  Min_TemperatureF  \
# 0  10/13/2014                 71                62.0                54
# 1  10/14/2014                 63                59.0                55
# 2  10/15/2014                 62                58.0                54
# 3  10/16/2014                 71                61.0                52
# 4  10/17/2014                 64                60.0                57
#
#    Max_Dew_Point_F  MeanDew_Point_F  Min_Dewpoint_F  Max_Humidity  \
# 0               55               51              46            87
# 1               52               51              50            88
# 2               53               50              46            87
# 3               49               46              42            83
# 4               55               51              41            87
#
#    Mean_Humidity  Min_Humidity   ...    Mean_Sea_Level_Pressure_In  \
# 0             68            46   ...                         29.79
# ...

# %%
we.Date = pd.to_datetime(we.Date)

# %%
we['MONTH'] = we.Date.dt.month

# %%
we.Precipitation_In.sum()/12
# Out:
# 6.0325

# %%
st.current_dockcount.mean()
# Out:
# 16.517241379310345

# %%
not_null = st.loc[pd.notnull(st.modification_date)]
is_null = st.loc[pd.isnull(st.modification_date)]

# %%
unmodified_checkedout = (not_null.install_dockcount - not_null.current_dockcount).mean()
modified_checkedout = (is_null.install_dockcount - is_null.current_dockcount).mean()

# %%
unmodified_checkedout
# Out:
# 3.764705882352941

# %%
is_null
# Out:
#    station_id                                               name        lat  \
# 0       BT-01                                 3rd Ave & Broad St  47.618418
# 1       BT-03                                  2nd Ave & Vine St  47.615829
# 2       BT-04                             6th Ave & Blanchard St  47.616094
# 3       BT-05                             2nd Ave & Blanchard St  47.613110
# 4      CBD-03                                 7th Ave & Union St  47.610731
# 5      CBD-04                                 Union St & 4th Ave  47.609221
# 6      CBD-05                                1st Ave & Marion St  47.604058
# 8      CBD-07                     City Hall / 4th Ave & James St  47.603509
# 9      CBD-13                                  2nd Ave & Pine St  47.610185
# 11      CH-01                           Summit Ave & E Denny Way  47.618633
# 13      CH-03                     Summit Ave E & E Republican St  47.623367
# ...
